# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
df=pd.read_csv(r"D:\ACADEMICS\TE-IT SEM5\ml lab\2.temperatures.csv")
df
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# ...

# %%
df.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %%
df.shape
# Out:
# (117, 18)

# %%
df.info
# Out:
# <bound method DataFrame.info of      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
# ...

# %%
count=(df["JAN"]==23.44).sum()
count
# Out:
# 1

# %%
df.corr()
# Out:
#              YEAR       JAN       FEB       MAR       APR       MAY       JUN  \
# YEAR     1.000000  0.575499  0.647066  0.553886  0.540662  0.407648  0.371840
# JAN      0.575499  1.000000  0.647017  0.457081  0.594674  0.365236  0.292855
# FEB      0.647066  0.647017  1.000000  0.589088  0.548803  0.377722  0.341302
# MAR      0.553886  0.457081  0.589088  1.000000  0.618621  0.387756  0.228349
# APR      0.540662  0.594674  0.548803  0.618621  1.000000  0.563317  0.299866
# MAY      0.407648  0.365236  0.377722  0.387756  0.563317  1.000000  0.274521
# JUN      0.371840  0.292855  0.341302  0.228349  0.299866  0.274521  1.000000
# JUL      0.478512  0.339337  0.418956  0.232647  0.286052  0.299072  0.480925
# AUG      0.654138  0.459944  0.503188  0.382344  0.490668  0.473171  0.504354
# SEP      0.664008  0.499764  0.472755  0.370066  0.437970  0.347289  0.305761
# OCT      0.589073  0.480695  0.466916  0.312226  0.473873  0.468993  0.380782
# ...

# %%
x=df.loc[:,"YEAR"].values.reshape(-1,1)
y=df.loc[:,"ANNUAL"].values.reshape(-1,1)
plt.plot(x,y,"*")

# %%
type(x)
type(y)
# Out:
# numpy.ndarray

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.75)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (87, 1)
# (30, 1)
# (87, 1)
# (30, 1)

# %%
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_test_prediction=regressor.predict(x_test)
y_train_prediction=regressor.predict(x_train)

# %%
#model visualize
plt.scatter(x_test,y_test,c="red")
plt.xlabel("YEAR")
plt.ylabel("TEMPERATURE")
#regression line
plt.plot(x_test,y_test_prediction,"-")

# %%
#test prediction error
MAE=mean_absolute_error(y_test,y_test_prediction)
print("MAE",MAE)
MSE = mean_squared_error(y_test,y_test_prediction)
print("MSE",MSE)
r1 = r2_score(y_test,y_test_prediction)
print("RSquare" , r1)

#train prediction error
MAE=mean_absolute_error(y_train,y_train_prediction)
print("MAE",MAE)
MSE = mean_squared_error(y_train,y_train_prediction)
print("MSE",MSE)
r1 = r2_score(y_train,y_train_prediction)
print("RSquare" , r1)
# Out:
# MAE 0.27398009944137297
# MSE 0.17162975184610205
# RSquare 0.5779591653611318
# MAE 0.20530070400974135
# MSE 0.08901411668761178
# RSquare 0.6674899374565533

# %% [markdown]
# ## HIGHLY CORRELATED

# %%
xh=df.loc[:,"DEC"].values.reshape(-1,1)
yh=df.loc[:,"ANNUAL"].values.reshape(-1,1)

# %%
xh_train,xh_test,yh_train,yh_test=train_test_split(xh,yh,train_size=0.75)

# %%
hmodel=LinearRegression()
hmodel.fit(xh_train,yh_train)
# Out:
# LinearRegression()

# %%
yh_test_prediction=hmodel.predict(xh_test)
yh_train_prediction=hmodel.predict(xh_train)

# %%
#test prediction error
MAE=mean_absolute_error(yh_test,yh_test_prediction)
print("MAE",MAE)
MSE = mean_squared_error(yh_test,yh_test_prediction)
print("MSE",MSE)
r1 = r2_score(yh_test,yh_test_prediction)
print("RSquare" , r1)

#train prediction error
MAE=mean_absolute_error(yh_train,yh_train_prediction)
print("MAE",MAE)
MSE = mean_squared_error(yh_train,yh_train_prediction)
print("MSE",MSE)
r1 = r2_score(yh_train,yh_train_prediction)
print("RSquare" , r1)
# Out:
# MAE 0.2178592159195483
# MSE 0.0800348609130162
# RSquare 0.5751253729499022
# MAE 0.24225232169172367
# MSE 0.09180745642980245
# RSquare 0.7242671006034402

# %% [markdown]
# ## LEAST CORRELATED

# %%
xl=df.loc[:,"JUN"].values.reshape(-1,1)
yl=df.loc[:,"ANNUAL"].values.reshape(-1,1)

# %%
xl_train,xl_test,yl_train,yl_test=train_test_split(xl,yl,train_size=0.75)

# %%
lmodel=LinearRegression()
lmodel.fit(xl_train,yl_train)
# Out:
# LinearRegression()

# %%
yl_test_prediction=lmodel.predict(xl_test)
yl_train_prediction=lmodel.predict(xl_train)

# %%
#test prediction error
MAE=mean_absolute_error(yl_test,yl_test_prediction)
print("MAE",MAE)
MSE = mean_squared_error(yl_test,yl_test_prediction)
print("MSE",MSE)
r1 = r2_score(yl_test,yl_test_prediction)
print("RSquare" , r1)

#train prediction error
MAE=mean_absolute_error(yl_train,yl_train_prediction)
print("MAE",MAE)
MSE = mean_squared_error(yl_train,yl_train_prediction)
print("MSE",MSE)
r1 = r2_score(yl_train,yl_train_prediction)
print("RSquare" , r1)
# Out:
# MAE 0.4464666771511117
# MSE 0.31899131220992183
# RSquare -0.0030314700136762074
# MAE 0.3345211845464826
# MSE 0.1952366025404051
# RSquare 0.33513810736409133

# %% [markdown]
# ## COMPARISON OF DIFFERENT TEST SIZE MODELS

# %%
train_sse=[]
test_sse=[]
for i in range (1,10):
    i/=10.0
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=i,random_state=2)
    model=LinearRegression()
    model.fit(x_train,y_train)
    
    y_test_predicted=model.predict(x_test)
    y_train_predicted=model.predict(x_train)
    
    train_sse.append(np.sum((y_train_predicted-y_train)**2)) 
    test_sse.append(np.sum((y_test_predicted-y_test)**2))
plt.plot(test_sse,'b',label="test")
plt.plot(train_sse,'r',label="train")
plt.show()
